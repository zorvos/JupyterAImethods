# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Load the data
data = pd.read_csv('IBM2017.csv')

# %%
# Ensure the 'Date' column is in datetime format and set it as the index
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
# Extract temporal features
data['Year'] = data.index.year
data['Month'] = data.index.month
data['Day'] = data.index.day

# %%
# Prepare features and target variable
# Use temporal features and 'Volume' as features
X = data[['Year', 'Month', 'Day', 'Volume']]
y = data['Close']  # Target: closing price

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train the Random Forest model
rf = RandomForestRegressor(n_estimators=100, random_state=0)  # You can adjust 'n_estimators' and other parameters
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# Make predictions
y_pred = rf.predict(X_test)

# %%
# Evaluate performance
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.018019922879596296

# %%
# Plot for visualization of results
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'], label='Actual Prices', color='blue')

# %%
# Scatter plot of predictions on the test set
plt.scatter(X_test.index, y_pred, color='red', label='Predictions')

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('IBM Stock Price Prediction using Random Forest Regression')
plt.legend()
plt.show()

# %% [markdown]
# Explanation of the Code:

# %% [markdown]
#     Load the Data:
#         Read the IBM stock data from a CSV file.

# %% [markdown]
#     Convert Dates and Extract Features:
#         Convert the Date column to datetime format and set it as the index.
#         Extract temporal features: year, month, and day.
#         Use the Volume feature as an additional input feature.

# %% [markdown]
#     Prepare Features and Target Variable:
#         X includes the temporal features (Year, Month, Day) and Volume.
#         y contains the closing prices.

# %% [markdown]
#     Split the Data:
#         Split the data into training and test sets.

# %% [markdown]
#     Train the Random Forest Model:
#         Fit a Random Forest regression model on the training data. You can adjust the number of estimators (n_estimators) and other hyperparameters as needed.

# %% [markdown]
#     Make Predictions and Evaluate:
#         Predict the closing prices on the test set and calculate the Mean Squared Error (MSE) to assess performance.

# %% [markdown]
#     Plot Results:
#         Plot the actual closing prices and the predictions to visualize the results.

# %% [markdown]
# Notes:

# %% [markdown]
#     Adjust the n_estimators parameter and other hyperparameters of the Random Forest model based on your specific requirements and dataset.
#     If you have additional features or data preprocessing steps, include them to potentially improve the model's performance.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d6ccbe74-5722-4f84-8e54-7da9a834c88a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
